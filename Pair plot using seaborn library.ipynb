# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
df = pd.read_csv("auto_data.csv")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
#defining function to modify origin

#1-USA,2-Europe,3-Asia

def origin(num):
    if num=='1':
        return 'USA'
    elif num=='2':
        return 'Europe'
    else:
        return 'Asia'
    
df['origin']=df['origin'].apply(ori)

df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
#use seaborn for pairplot and set size=4
#hue is variable in dataset to map plot the aspects to different colors

sb.pairplot(df[['mpg','weight','origin']],hue='origin',size=4)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python37\Lib\site-packages\seaborn\axisgrid.py:1969: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
