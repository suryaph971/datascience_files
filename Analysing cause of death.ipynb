# %% [markdown]
# #### 1: List the causes of death and percentile in Ohio state in the year 2012

# %%
#import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# View the plot 
# %matplotlib inline

# %%
#cause of deaths

cause=['Chronic Disease', 'Unintetional Injuries', 'Alzheimers', 'Infuenza and Pneumonia', 'Sepsis','Others']

#percentile
percentile = [62, 5, 4, 2, 1 , 26]

# %% [markdown]
# #### 2: Draw a pie chart using the two data points

# %%
#set the pie chart plot properties
labels = 'Chronic Disease', 'Unintetional Injuries', 'Alzheimers', 'Infuenza and Pneumonia', 'Sepsis','Others'

explode = (0.05,0,0,0,0,0)

# %%
#set figure size
plt.figure(figsize=(6,6))

# %%
#explode the largest pie in the data set
explode = (0.05,0,0,0,0,0)

# %%
#set pie chart properties
plt.pie(percentile,labels=labels,explode=explode,autopct='%1.1f%%',startangle=70)
plt.axis('equal')
plt.title('Ohio state')
plt.show()

# %%
#set axis equal to draw pie as circle
plt.axis('equal')
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
#set title of the pie chart
plt.title('Ohio state')
# Out:
# Text(0.5, 1.0, 'Ohio state')

# %%
#show the plot (pie chart)
plt.show()
